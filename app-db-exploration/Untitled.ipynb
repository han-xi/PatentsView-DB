# %%
import xml.etree.ElementTree as ET

# %%
tree=ET.parse("US20190215000A1-20190711.XML")

# %%
root=tree.getroot()

# %%
root.attrib
# Out:
# {'lang': 'EN',
#  'dtd-version': 'v4.4 2014-04-03',
#  'file': 'US20190215000A1-20190711.XML',
#  'status': 'PRODUCTION',
#  'id': 'us-patent-application',
#  'country': 'US',
#  'date-produced': '20190626',
#  'date-publ': '20190711'}

# %%
tree_structure={}

# %%
def print_children(element, tree_structure={},level=0):
    for child in element:
        prefix=level*"\t"
        print(prefix+child.tag)
        children=child.getchildren()
        if children:
            tree_structure[child.tag]={"derived-db-fields":[]}
            tree_structure[child.tag]=print_children(child, tree_structure[child.tag],level+1)
        else:
            tree_structure[child.tag]=[{"db-field":child.tag,"existing":True}]
    return tree_structure

# %%
tree_structure
# Out:
# {'us-bibliographic-data-application': {'publication-reference': {'document-id': {'country': 'country',
#     'doc-number': 'doc-number',
#     'kind': 'kind',
#     'date': 'date'}},
#   'application-reference': {'document-id': {'country': 'country',
#     'doc-number': 'doc-number',
#     'date': 'date'}},
#   'us-application-series-code': 'us-application-series-code',
#   'classifications-ipcr': {'classification-ipcr': {'ipc-version-indicator': {'date': 'date'},
#     'classification-level': 'classification-level',
#     'section': 'section',
#     'class': 'class',
#     'subclass': 'subclass',
#     'main-group': 'main-group',
#     'subgroup': 'subgroup',
#     'symbol-position': 'symbol-position',
#     'classification-value': 'classification-value',
#     'action-date': {'date': 'date'},
#     'generating-office': {'country': 'country'},
#     'classification-status': 'classification-status',
#     'classification-data-source': 'classification-data-source'}},
#   'classifications-cpc': {'main-cpc': {'classification-cpc': {'cpc-version-indicator': {'date': 'date'},
#      'section': 'section',
#      'class': 'class',
#      'subclass': 'subclass',
#      'main-group': 'main-group',
#      'subgroup': 'subgroup',
#      'symbol-position': 'symbol-position',
#      'classification-value': 'classification-value',
#      'action-date': {'date': 'date'},
#      'generating-office': {'country': 'country'},
#      'classification-status': 'classification-status',
#      'classification-data-source': 'classification-data-source',
#      'scheme-origination-code': 'scheme-origination-code'}},
#    'further-cpc': {'classification-cpc': {'cpc-version-indicator': {'date': 'date'},
#      'section': 'section',
#      'class': 'class',
#      'subclass': 'subclass',
#      'main-group': 'main-group',
#      'subgroup': 'subgroup',
#      'symbol-position': 'symbol-position',
#      'classification-value': 'classification-value',
#      'action-date': {'date': 'date'},
#      'generating-office': {'country': 'country'},
#      'classification-status': 'classification-status',
#      'classification-data-source': 'classification-data-source',
#      'scheme-origination-code': 'scheme-origination-code'}}},
#   'invention-title': 'invention-title',
#   'us-parties': {'us-applicants': {'us-applicant': {'addressbook': {'orgname': 'orgname',
#       'address': {'city': 'city', 'state': 'state', 'country': 'country'}},
#      'residence': {'country': 'country'}}},
#    'inventors': {'inventor': {'addressbook': {'last-name': 'last-name',
#       'first-name': 'first-name',
#       'address': {'city': 'city', 'state': 'state', 'country': 'country'}}}}}},
#  'abstract': {'p': 'p'},
#  'drawings': {'figure': {'img': 'img'}},
#  'description': {'heading': 'heading',
#   'p': 'p',
#   'description-of-drawings': {'heading': 'heading',
#    'p': {'figref': 'figref'}}},
#  'us-claim-statement': 'us-claim-statement',
#  'claims': {'claim': {'claim-text': {'b': 'b', 'claim-ref': 'claim-ref'}}}}

# %%
tree_structure=print_children(root, tree_structure)
# Out:
# us-bibliographic-data-application
# 	publication-reference
# 		document-id
# 			country
# 			doc-number
# 			kind
# 			date
# 	application-reference
# 		document-id
# 			country
# 			doc-number
# 			date
# 	us-application-series-code
# 	classifications-ipcr
# 		classification-ipcr
# 			ipc-version-indicator
# 				date
# 			classification-level
# 			section
# 			class
# 			subclass
# 			main-group
# 			subgroup
# 			symbol-position
# 			classification-value
# 			action-date
# 				date
# 			generating-office
# 				country
# 			classification-status
# 			classification-data-source
# 		classification-ipcr
# 			ipc-version-indicator
# 				date
# 			classification-level
# 			section
# 			class
# 			subclass
# 			main-group
# 			subgroup
# 			symbol-position
# 			classification-value
# 			action-date
# 				date
# 			generating-office
# 				country
# 			classification-status
# 			classification-data-source
# 		classification-ipcr
# 			ipc-version-indicator
# 				date
# 			classification-level
# 			section
# 			class
# 			subclass
# 			main-group
# 			subgroup
# 			symbol-position
# 			classification-value
# 			action-date
# 				date
# 			generating-office
# 				country
# 			classification-status
# 			classification-data-source
# 	classifications-cpc
# 		main-cpc
# 			classification-cpc
# 				cpc-version-indicator
# 					date
# 				section
# 				class
# 				subclass
# 				main-group
# 				subgroup
# 				symbol-position
# 				classification-value
# 				action-date
# 					date
# 				generating-office
# 					country
# 				classification-status
# 				classification-data-source
# 				scheme-origination-code
# 		further-cpc
# 			classification-cpc
# 				cpc-version-indicator
# 					date
# 				section
# 				class
# 				subclass
# 				main-group
# 				subgroup
# 				symbol-position
# 				classification-value
# 				action-date
# 					date
# 				generating-office
# 					country
# 				classification-status
# 				classification-data-source
# 				scheme-origination-code
# 			classification-cpc
# 				cpc-version-indicator
# 					date
# 				section
# 				class
# 				subclass
# 				main-group
# 				subgroup
# 				symbol-position
# 				classification-value
# 				action-date
# 					date
# 				generating-office
# 					country
# 				classification-status
# 				classification-data-source
# 				scheme-origination-code
# 	invention-title
# 	us-parties
# 		us-applicants
# 			us-applicant
# 				addressbook
# 					orgname
# 					address
# 						city
# 						state
# 						country
# 				residence
# 					country
# 		inventors
# 			inventor
# 				addressbook
# 					last-name
# 					first-name
# 					address
# 						city
# 						state
# 						country
# 			inventor
# 				addressbook
# 					last-name
# 					first-name
# 					address
# 						city
# 						state
# 						country
# abstract
# 	p
# drawings
# 	figure
# 		img
# 	figure
# 		img
# 	figure
# 		img
# 	figure
# 		img
# 	figure
# 		img
# 	figure
# 		img
# 	figure
# 		img
# 	figure
# 		img
# 	figure
# 		img
# 	figure
# 		img
# description
# 	heading
# 	p
# 	heading
# 	p
# 	heading
# 	p
# 	p
# 	p
# 	p
# 	description-of-drawings
# 		heading
# 		p
# 		p
# 			figref
# 		p
# 			figref
# 		p
# 			figref
# 		p
# 			figref
# 		p
# 			figref
# 		p
# 			figref
# 		p
# 			figref
# 		p
# 			figref
# 		p
# 			figref
# 	heading
# 	p
# 	p
# 	p
# 	heading
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		figref
# 	p
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 		sub
# 		sub
# 		b
# 		sub
# 		sub
# 	p
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 	p
# 		figref
# 		b
# 		b
# 		i
# 		b
# 		i
# 		b
# 		b
# 		sub
# 		b
# 		i
# 		b
# 		i
# 		b
# 		i
# 		sub
# 		b
# 		i
# 		b
# 		i
# 		b
# 		i
# 		sub
# 		b
# 		i
# 		b
# 		i
# 		b
# 		b
# 		sub
# 		sub
# 		sub
# 		sub
# 		sub
# 		sub
# 	p
# 		b
# 		b
# 		b
# 		b
# 		b
# 		sub
# 		sub
# 		sub
# 		b
# 		b
# 		sub
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		sub
# 		b
# 	p
# 		b
# 		sub
# 		b
# 		i
# 		b
# 		i
# 		sub
# 		b
# 		b
# 		b
# 		b
# 		b
# 		sub
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 		b
# 		sub
# 		b
# 		b
# 		b
# 		b
# 		sub
# 		sub
# 		b
# 		b
# 		sub
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 		sub
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		figref
# 	heading
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 	heading
# 	p
# 		b
# 		b
# 		figref
# 	p
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 	p
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 	p
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 		b
# 	p
# 		figref
# 		figref
# 		b
# 		figref
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		figref
# 		b
# 		b
# 	p
# 		figref
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 		b
# 		figref
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 	p
# 		b
# 		b
# 	p
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		figref
# 		b
# 		b
# 		b
# 	p
# 		figref
# 		b
# 		b
# 		b
# 		figref
# 		b
# 		figref
# 	p
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 	p
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 		b
# 	p
# 		b
# 		b
# 	p
# 	p
# 		b
# 		b
# 		b
# 		b
# 		b
# 	p
# 	p
# 	p
# 		b
# 	p
# 	p
# 	p
# 	p
# 		b
# 		figref
# 		b
# 		b
# 		figref
# 		b
# 		figref
# 		b
# 		b
# 		figref
# 		b
# 		b
# 		b
# 		figref
# 	p
# 	p
# 	p
# 	p
# 	p
# us-claim-statement
# claims
# 	claim
# 		claim-text
# 			b
# 			claim-text
# 			claim-text
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 			claim-text
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 			claim-text
# 			claim-text
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-text
# 			claim-text
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-text
# 			claim-text
# 			claim-text
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 			claim-text
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref
# 	claim
# 		claim-text
# 			b
# 			claim-ref

# %%
import pprint

# %%
json.dump(tree_structure, open("xml_struct.json","w"))
