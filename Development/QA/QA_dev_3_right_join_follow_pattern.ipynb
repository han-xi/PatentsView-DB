# %%
#Right Joins That Follow Pattern
import pandas as pd
import os
import configparser
import sys
sys.path.append('/project/Development')
from helpers import general_helpers
import configparser
config = configparser.ConfigParser()
config.read('/project/Development/config.ini')
host = config['DATABASE']['HOST']
username = config['DATABASE']['USERNAME']
password = config['DATABASE']['PASSWORD']
new_database = config['DATABASE']['NEW_DB']
old_database = config['DATABASE']['OLD_DB']
temporary_upload = config['DATABASE']['TEMP_UPLOAD_DB']
previous_qa_loc = config['FOLDERS']['OLD_QA_LOC']
new_qa_loc = config['FOLDERS']['NEW_QA_LOC']
latest_expected_date = config['CONSTANTS']['LATEST_DATE']

engine = general_helpers.connect_to_db(host, username, password, new_database)
data_list = [(['patent', 'id'], ['application', 'patent_id']), (['temp_patent_list', 'id'], ['application', 'patent_id']), (['patent', 'id'], ['brf_sum_text', 'patent_id']), (['temp_patent_list', 'id'], ['brf_sum_text', 'patent_id']), (['patent', 'id'], ['claim', 'patent_id']), (['temp_patent_list', 'id'], ['claim', 'patent_id']), (['patent', 'id'], ['cpc_current', 'patent_id']), (['temp_patent_list', 'id'], ['cpc_current', 'patent_id']), (['patent', 'id'], ['detail_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['detail_desc_text', 'patent_id']), (['patent', 'id'], ['draw_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['draw_desc_text', 'patent_id']), (['patent', 'id'], ['figures', 'patent_id']), (['temp_patent_list', 'id'], ['figures', 'patent_id']), (['patent', 'id'], ['foreign_priority', 'patent_id']), (['temp_patent_list', 'id'], ['foreign_priority', 'patent_id']), (['patent', 'id'], ['foreigncitation', 'patent_id']), (['temp_patent_list', 'id'], ['foreigncitation', 'patent_id']), (['patent', 'id'], ['government_interest', 'patent_id']), (['temp_patent_list', 'id'], ['government_interest', 'patent_id']), (['patent', 'id'], ['ipcr', 'patent_id']), (['temp_patent_list', 'id'], ['ipcr', 'patent_id']),  (['patent', 'id'], ['nber', 'patent_id']), (['temp_patent_list', 'id'], ['nber', 'patent_id']), (['patent', 'id'], ['non_inventor_applicant', 'patent_id']), (['temp_patent_list', 'id'], ['non_inventor_applicant', 'patent_id']), (['patent', 'id'], ['otherreference', 'patent_id']), (['temp_patent_list', 'id'], ['otherreference', 'patent_id']), (['patent', 'id'], ['patent_assignee', 'patent_id']), (['temp_patent_list', 'id'], ['patent_assignee', 'patent_id']), (['assignee', 'id'], ['patent_assignee', 'assignee_id']), (['patent', 'id'], ['patent_contractawardnumber', 'patent_id']), (['temp_patent_list', 'id'], ['patent_contractawardnumber', 'patent_id']), (['patent', 'id'], ['patent_govintorg', 'patent_id']), (['temp_patent_list', 'id'], ['patent_govintorg', 'patent_id']), (['government_organization', 'organization_id'], ['patent_govintorg', 'organization_id']), (['patent', 'id'], ['patent_inventor', 'patent_id']), (['temp_patent_list', 'id'], ['patent_inventor', 'patent_id']), (['inventor', 'id'], ['patent_inventor', 'inventor_id']), (['patent', 'id'], ['patent_lawyer', 'patent_id']), (['temp_patent_list', 'id'], ['patent_lawyer', 'patent_id']), (['lawyer', 'id'], ['patent_lawyer', 'lawyer_id']), (['patent', 'id'], ['pct_data', 'patent_id']), (['temp_patent_list', 'id'], ['pct_data', 'patent_id']), (['patent', 'id'], ['rawassignee', 'patent_id']), (['temp_patent_list', 'id'], ['rawassignee', 'patent_id']), (['assignee', 'id'], ['rawassignee', 'assignee_id']), (['patent', 'id'], ['rawexaminer', 'patent_id']), (['temp_patent_list', 'id'], ['rawexaminer', 'patent_id']),   (['patent', 'id'], ['rawlawyer', 'patent_id']), (['temp_patent_list', 'id'], ['rawlawyer', 'patent_id']), (['lawyer', 'id'], ['rawlawyer', 'lawyer_id']), (['patent', 'id'], ['rel_app_text', 'patent_id']), (['temp_patent_list', 'id'], ['rel_app_text', 'patent_id']), (['patent', 'id'], ['us_term_of_grant', 'patent_id']), (['temp_patent_list', 'id'], ['us_term_of_grant', 'patent_id']), (['patent', 'id'], ['usapplicationcitation', 'patent_id']), (['temp_patent_list', 'id'], ['usapplicationcitation', 'patent_id']), (['patent', 'id'], ['uspatentcitation', 'patent_id']), (['temp_patent_list', 'id'], ['uspatentcitation', 'patent_id']), (['patent', 'id'], ['uspc_current', 'patent_id']), (['temp_patent_list', 'id'], ['uspc_current', 'patent_id']), (['patent', 'id'], ['uspc', 'patent_id']), (['temp_patent_list', 'id'], ['uspc', 'patent_id']), (['patent', 'id'], ['usreldoc', 'patent_id']), (['temp_patent_list', 'id'], ['usreldoc', 'patent_id']), (['patent', 'id'], ['wipo', 'patent_id']), (['temp_patent_list', 'id'], ['wipo', 'patent_id'])]

right_joins = []
id_list=[]
for i, j in data_list:
    conn = engine.connect()
    var = conn.execute("select count(distinct {0}.{1}) from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null".format(i[0], i[1], j[0], j[1]))
    count = [row[0] for row in var][0]
    print (count)
    right_joins.append("There are {0} rows in {1} not in {2}".format(count, i[0], j[0]))
    if count >0: #ie if there are any rows in the left table not in the right 
        ids_sql = pd.read_sql("select distinct {0}.{1} from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null limit 5".format(i[0], i[1], j[0], j[1]), conn)
        print (ids_sql)
        ids= ids_sql.values.T.tolist()
        id_list.append(ids[0])
    else:
        id_list.append('none')
conn.close()
# Out:
# 0
# 0
# 593385
#         id
# 0  3930397
# 1  3930496
# 2  3931131
# 3  3931152
# 4  3931271
# 15494
#         id
# 0  D819295
# 1  D819296
# 2  D819297
# 3  D819298
# 4  D819299

# %%
#Right Joins That Follow Pattern
import pandas as pd
import os
import configparser
import sys
sys.path.append('/project/Development')
from helpers import general_helpers
import configparser
config = configparser.ConfigParser()
config.read('/project/Development/config.ini')
host = config['DATABASE']['HOST']
username = config['DATABASE']['USERNAME']
password = config['DATABASE']['PASSWORD']
new_database = config['DATABASE']['NEW_DB']
old_database = config['DATABASE']['OLD_DB']
temporary_upload = config['DATABASE']['TEMP_UPLOAD_DB']
previous_qa_loc = config['FOLDERS']['OLD_QA_LOC']
new_qa_loc = config['FOLDERS']['NEW_QA_LOC']
latest_expected_date = config['CONSTANTS']['LATEST_DATE']

engine = general_helpers.connect_to_db(host, username, password, new_database)
data = pd.read_excel("{}/3_right_joins_standard.xlsx".format(previous_qa_loc))

data_list = [(['patent', 'id'], ['application', 'patent_id']), (['temp_patent_list', 'id'], ['application', 'patent_id']), (['patent', 'id'], ['brf_sum_text', 'patent_id']), (['temp_patent_list', 'id'], ['brf_sum_text', 'patent_id']), (['patent', 'id'], ['claim', 'patent_id']), (['temp_patent_list', 'id'], ['claim', 'patent_id']), (['patent', 'id'], ['cpc_current', 'patent_id']), (['temp_patent_list', 'id'], ['cpc_current', 'patent_id']), (['patent', 'id'], ['detail_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['detail_desc_text', 'patent_id']), (['patent', 'id'], ['draw_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['draw_desc_text', 'patent_id']), (['patent', 'id'], ['figures', 'patent_id']), (['temp_patent_list', 'id'], ['figures', 'patent_id']), (['patent', 'id'], ['foreign_priority', 'patent_id']), (['temp_patent_list', 'id'], ['foreign_priority', 'patent_id']), (['patent', 'id'], ['foreigncitation', 'patent_id']), (['temp_patent_list', 'id'], ['foreigncitation', 'patent_id']), (['patent', 'id'], ['government_interest', 'patent_id']), (['temp_patent_list', 'id'], ['government_interest', 'patent_id']), (['patent', 'id'], ['ipcr', 'patent_id']), (['temp_patent_list', 'id'], ['ipcr', 'patent_id']),  (['patent', 'id'], ['nber', 'patent_id']), (['temp_patent_list', 'id'], ['nber', 'patent_id']), (['patent', 'id'], ['non_inventor_applicant', 'patent_id']), (['temp_patent_list', 'id'], ['non_inventor_applicant', 'patent_id']), (['patent', 'id'], ['otherreference', 'patent_id']), (['temp_patent_list', 'id'], ['otherreference', 'patent_id']), (['patent', 'id'], ['patent_assignee', 'patent_id']), (['temp_patent_list', 'id'], ['patent_assignee', 'patent_id']), (['assignee', 'id'], ['patent_assignee', 'assignee_id']), (['patent', 'id'], ['patent_contractawardnumber', 'patent_id']), (['temp_patent_list', 'id'], ['patent_contractawardnumber', 'patent_id']), (['patent', 'id'], ['patent_govintorg', 'patent_id']), (['temp_patent_list', 'id'], ['patent_govintorg', 'patent_id']), (['government_organization', 'organization_id'], ['patent_govintorg', 'organization_id']), (['patent', 'id'], ['patent_inventor', 'patent_id']), (['temp_patent_list', 'id'], ['patent_inventor', 'patent_id']), (['inventor', 'id'], ['patent_inventor', 'inventor_id']), (['patent', 'id'], ['patent_lawyer', 'patent_id']), (['temp_patent_list', 'id'], ['patent_lawyer', 'patent_id']), (['lawyer', 'id'], ['patent_lawyer', 'lawyer_id']), (['patent', 'id'], ['pct_data', 'patent_id']), (['temp_patent_list', 'id'], ['pct_data', 'patent_id']), (['patent', 'id'], ['rawassignee', 'patent_id']), (['temp_patent_list', 'id'], ['rawassignee', 'patent_id']), (['assignee', 'id'], ['rawassignee', 'assignee_id']), (['patent', 'id'], ['rawexaminer', 'patent_id']), (['temp_patent_list', 'id'], ['rawexaminer', 'patent_id']),   (['patent', 'id'], ['rawlawyer', 'patent_id']), (['temp_patent_list', 'id'], ['rawlawyer', 'patent_id']), (['lawyer', 'id'], ['rawlawyer', 'lawyer_id']), (['patent', 'id'], ['rel_app_text', 'patent_id']), (['temp_patent_list', 'id'], ['rel_app_text', 'patent_id']), (['patent', 'id'], ['us_term_of_grant', 'patent_id']), (['temp_patent_list', 'id'], ['us_term_of_grant', 'patent_id']), (['patent', 'id'], ['usapplicationcitation', 'patent_id']), (['temp_patent_list', 'id'], ['usapplicationcitation', 'patent_id']), (['patent', 'id'], ['uspatentcitation', 'patent_id']), (['temp_patent_list', 'id'], ['uspatentcitation', 'patent_id']), (['patent', 'id'], ['uspc_current', 'patent_id']), (['temp_patent_list', 'id'], ['uspc_current', 'patent_id']), (['patent', 'id'], ['uspc', 'patent_id']), (['temp_patent_list', 'id'], ['uspc', 'patent_id']), (['patent', 'id'], ['usreldoc', 'patent_id']), (['temp_patent_list', 'id'], ['usreldoc', 'patent_id']), (['patent', 'id'], ['wipo', 'patent_id']), (['temp_patent_list', 'id'], ['wipo', 'patent_id'])]
def right_joins(new_database, previous_qa_loc, new_qa_loc):
        '''new_database: new database
	   previous_qa_loc: location of previous qa document
	   new_qa_loc: location of new qa document
	   this function does all right joins that follow the same pattern 
	   in the new database and writes output to a csv file'''
        results = pd.read_excel("{0}/3_right_joins_standard.xlsx".format(previous_qa_loc))
        right_joins = []
        id_list=[]
        for i, j in data_list:
            conn = engine.connect()
            var = conn.execute("select count(distinct {0}.{1}) from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null".format(i[0], i[1], j[0], j[1]))
            count = [row[0] for row in var][0]
            print (count)
            right_joins.append("There are {0} rows in {1} not in {2}".format(count, i[0], j[0]))
            if count >0: #ie if there are any rows in the left table not in the right 
                ids_sql = pd.read_sql("select distinct {0}.{1} from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null limit 5".format(i[0], i[1], j[0], j[1]), conn)
                print (ids_sql)
                ids= ids_sql.values.T.tolist()
                id_list.append(ids[0])
            else:
                id_list.append('none')
        conn.close()
        return right_joins, id_list
        results['Description_{0}'.format(new_database)]= right_joins
        results['Example missing IDS_{0}'.format(new_database)]= id_list

def write_standard(right_joins,id_list, new_database, previous_qa_loc, new_qa_loc ):
	results.to_csv("{0}/09_right_joins.csv".format(new_qa_loc), index = False)
	
right_joins_id_list= right_joins(new_database, previous_qa_loc, new_qa_loc)
write_standard(right_joins_id_list, new_database, previous_qa_loc, new_qa_loc)
# Out:
# 0
# 0
# 593385
#         id
# 0  3930397
# 1  3930496
# 2  3931131
# 3  3931152
# 4  3931271
# 15494
#         id
# 0  D819295
# 1  D819296
# 2  D819297
# 3  D819298
# 4  D819299
# 624
#         id
# 0  3936360
# 1  3952053
# 2  3953462
# 3  3972791
# 4  3977862
# 0
# 671819
#         id
# 0  3931164
# 1  3931165
# 2  3931280
# 3  3931291
# 4  3931308
# 42384
#         id
# 0  9986793
# 1  9986961
# 2  9988557
# 3  9989676
# 4  9989685
# 2862903
#         id
# 0  3930271
# 1  3930273
# 2  3930276
# 3  3930278
# 4  3930279
# 15494
#         id
# 0  D819295
# 1  D819296
# 2  D819297
# 3  D819298
# 4  D819299
# 653300
#         id
# 0  3930407
# 1  3930426
# 2  3930504
# 3  3930532
# 4  3930537
# 6019
#         id
# 0  9986700
# 1  9986701
# 2  9986702
# 3  9986703
# 4  9986704
# 506049
#         id
# 0  3930407
# 1  3930671
# 2  3930672
# 3  3930791
# 4  3930792
# 5637
#         id
# 0  9986700
# 1  9986701
# 2  9986702
# 3  9986703
# 4  9986704
# 4275459
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 108018
#         id
# 0  9986671
# 1  9986672
# 2  9986673
# 3  9986674
# 4  9986675
# 3180843
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930276
# 60348
#         id
# 0  9986671
# 1  9986674
# 2  9986675
# 3  9986681
# 4  9986682
# 6681634
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 167963
#         id
# 0  9986671
# 1  9986672
# 2  9986673
# 3  9986674
# 4  9986675
# 440527
#         id
# 0  3930439
# 1  3931438
# 2  3932665
# 3  3932897
# 4  3935828
# 15494
#         id
# 0  D819295
# 1  D819296
# 2  D819297
# 3  D819298
# 4  D819299
# 1713425
#         id
# 0  3930271
# 1  D242583
# 2  D242584
# 3  D242585
# 4  D242586
# 171663
#         id
# 0  9986671
# 1  9986672
# 2  9986673
# 3  9986674
# 4  9986675
# 4866673
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 0
# 3814255
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 59439
#         id
# 0  9986672
# 1  9986673
# 2  9986674
# 3  9986675
# 4  9986676
# 945902
#         id
# 0  3930274
# 1  3930275
# 2  3930278
# 3  3930279
# 4  3930287
# 11764
#         id
# 0  9986672
# 1  9986675
# 2  9986694
# 3  9986695
# 4  9986697
# 0
# 6711080
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 168580
#         id
# 0  9986671
# 1  9986672
# 2  9986673
# 3  9986674
# 4  9986675
# 6684439
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 709, in _finalize_fairy
#     fairy._reset(pool)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 880, in _reset
#     pool._dialect.do_rollback(self)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py", line 1805, in do_rollback
#     dbapi_connection.rollback()
# _mysql_exceptions.OperationalError: (2006, 'MySQL server has gone away')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 709, in _finalize_fairy
#     fairy._reset(pool)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 880, in _reset
#     pool._dialect.do_rollback(self)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py", line 1805, in do_rollback
#     dbapi_connection.rollback()
# _mysql_exceptions.OperationalError: (2006, 'MySQL server has gone away')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 709, in _finalize_fairy
#     fairy._reset(pool)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 880, in _reset
#     pool._dialect.do_rollback(self)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py", line 1805, in do_rollback
#     dbapi_connection.rollback()
# _mysql_exceptions.OperationalError: (2006, 'MySQL server has gone away')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 709, in _finalize_fairy
#     fairy._reset(pool)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 880, in _reset
#     pool._dialect.do_rollback(self)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py", line 1805, in do_rollback
#     dbapi_connection.rollback()
# _mysql_exceptions.OperationalError: (2006, 'MySQL server has gone away')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 709, in _finalize_fairy
#     fairy._reset(pool)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 880, in _reset
#     pool._dialect.do_rollback(self)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py", line 1805, in do_rollback
#     dbapi_connection.rollback()
# _mysql_exceptions.OperationalError: (2006, 'MySQL server has gone away')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 709, in _finalize_fairy
#     fairy._reset(pool)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 880, in _reset
#     pool._dialect.do_rollback(self)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py", line 1805, in do_rollback
#     dbapi_connection.rollback()
# _mysql_exceptions.OperationalError: (2006, 'MySQL server has gone away')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 709, in _finalize_fairy
#     fairy._reset(pool)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 880, in _reset
#     pool._dialect.do_rollback(self)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py", line 1805, in do_rollback
#     dbapi_connection.rollback()
# _mysql_exceptions.OperationalError: (2006, 'MySQL server has gone away')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 709, in _finalize_fairy
#     fairy._reset(pool)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 880, in _reset
#     pool._dialect.do_rollback(self)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py", line 1805, in do_rollback
#     dbapi_connection.rollback()
# _mysql_exceptions.OperationalError: (2006, 'MySQL server has gone away')
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 709, in _finalize_fairy
#     fairy._reset(pool)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/pool.py", line 880, in _reset
#     pool._dialect.do_rollback(self)
#   File "/opt/conda/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/base.py", line 1805, in do_rollback
#     dbapi_connection.rollback()
# _mysql_exceptions.OperationalError: (2006, 'MySQL server has gone away')
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 168347
#         id
# 0  9986671
# 1  9986672
# 2  9986673
# 3  9986674
# 4  9986675
# 3
#    organization_id
# 0               93
# 1              250
# 2              251
# 842
#         id
# 0  3930271
# 1  3930272
# 2  3933099
# 3  3933186
# 4  3934407
# 1
#          id
# 0  10016888
# 9
#           id
# 0  4905162-2
# 1  6106870-2
# 2  7868820-1
# 3  7938029-1
# 4  8145560-4
# 513929
#         id
# 0  3930275
# 1  3930286
# 2  3930287
# 3  3930289
# 4  3930306
# 12525
#         id
# 0  9986678
# 1  9986680
# 2  9986685
# 3  9986688
# 4  9986697
# 6
#                                  id
# 0  32d80607adaf06f0d8251a1ff1d7e3f5
# 1  b0b9a26f8c239c07f80d6070c4285561
# 2  d19ee558dd64618f5ec89e86f3f7b958
# 3  d3cd6bd52692b0b31d18d4d929edefcc
# 4  d53491a2a4c691349470633bdf5bac3a
# 6163595
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 140324
#         id
# 0  9986671
# 1  9986672
# 2  9986673
# 3  9986674
# 4  9986675
# 945902
#         id
# 0  3930274
# 1  3930275
# 2  3930278
# 3  3930279
# 4  3930287
# 11764
#         id
# 0  9986672
# 1  9986675
# 2  9986694
# 3  9986695
# 4  9986697
# 0
# 1559
#         id
# 0  3930794
# 1  3931269
# 2  3933122
# 3  3933727
# 4  3934607
# 0
# 513929
#         id
# 0  3930275
# 1  3930286
# 2  3930287
# 3  3930289
# 4  3930306
# 12525
#         id
# 0  9986678
# 1  9986680
# 2  9986685
# 3  9986688
# 4  9986697
# 6
#                                  id
# 0  32d80607adaf06f0d8251a1ff1d7e3f5
# 1  b0b9a26f8c239c07f80d6070c4285561
# 2  d19ee558dd64618f5ec89e86f3f7b958
# 3  d3cd6bd52692b0b31d18d4d929edefcc
# 4  d53491a2a4c691349470633bdf5bac3a
# 5202160
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930275
# 4  3930276
# 106565
#         id
# 0  9986675
# 1  9986676
# 2  9986677
# 3  9986678
# 4  9986680
# 3603401
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 60154
#         id
# 0  9986671
# 1  9986672
# 2  9986673
# 3  9986677
# 4  9986683
# 4064799
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 15892
#         id
# 0  9986675
# 1  9986687
# 2  9986704
# 3  9986705
# 4  9986706
# 352977
#         id
# 0  3930335
# 1  3930349
# 2  3930361
# 3  3930944
# 4  3930945
# 22123
#         id
# 0  9986696
# 1  9986700
# 2  9986703
# 3  9986721
# 4  9986722
# 205527
#         id
# 0  6351496
# 1  6354624
# 2  6354730
# 3  6501280
# 4  6569898
# 168345
#         id
# 0  9986671
# 1  9986672
# 2  9986673
# 3  9986674
# 4  9986675
# 1764775
#         id
# 0  4942724
# 1  4985005
# 2  5156284
# 3  D336489
# 4  5300544
# 168345
#         id
# 0  9986671
# 1  9986672
# 2  9986673
# 3  9986674
# 4  9986675
# 3379013
#         id
# 0  3930271
# 1  3930272
# 2  3930273
# 3  3930274
# 4  3930275
# 22460
#         id
# 0  9986675
# 1  9986695
# 2  9986697
# 3  9986705
# 4  9986706
# 674486
#         id
# 0  3931164
# 1  3931165
# 2  3931280
# 3  3931291
# 4  3931308
# 42406
#         id
# 0  9986793
# 1  9986961
# 2  9988557
# 3  9989676
# 4  9989685
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c3a6da17b165> in <module>
#      54
#      55 right_joins_id_list= right_joins(new_database, previous_qa_loc, new_qa_loc)
# ---> 56 write_standard(right_joins_id_list, new_database, previous_qa_loc, new_qa_loc)
#
# TypeError: write_standard() missing 1 required positional argument: 'new_qa_loc'

# %%
#Right Joins That Follow Pattern
import pandas as pd
import os
import configparser
import sys
sys.path.append('/project/Development')
from helpers import general_helpers
import configparser
config = configparser.ConfigParser()
config.read('/project/Development/config.ini')
host = config['DATABASE']['HOST']
username = config['DATABASE']['USERNAME']
password = config['DATABASE']['PASSWORD']
new_database = config['DATABASE']['NEW_DB']
old_database = config['DATABASE']['OLD_DB']
temporary_upload = config['DATABASE']['TEMP_UPLOAD_DB']
previous_qa_loc = config['FOLDERS']['OLD_QA_LOC']
new_qa_loc = config['FOLDERS']['NEW_QA_LOC']
latest_expected_date = config['CONSTANTS']['LATEST_DATE']

engine = general_helpers.connect_to_db(host, username, password, new_database)
data = pd.read_excel("{}/3_right_joins_standard.xlsx".format(previous_qa_loc))

data_list = [(['patent', 'id'], ['application', 'patent_id']), (['temp_patent_list', 'id'], ['application', 'patent_id']), (['patent', 'id'], ['brf_sum_text', 'patent_id']), (['temp_patent_list', 'id'], ['brf_sum_text', 'patent_id']), (['patent', 'id'], ['claim', 'patent_id']), (['temp_patent_list', 'id'], ['claim', 'patent_id']), (['patent', 'id'], ['cpc_current', 'patent_id']), (['temp_patent_list', 'id'], ['cpc_current', 'patent_id']), (['patent', 'id'], ['detail_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['detail_desc_text', 'patent_id']), (['patent', 'id'], ['draw_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['draw_desc_text', 'patent_id']), (['patent', 'id'], ['figures', 'patent_id']), (['temp_patent_list', 'id'], ['figures', 'patent_id']), (['patent', 'id'], ['foreign_priority', 'patent_id']), (['temp_patent_list', 'id'], ['foreign_priority', 'patent_id']), (['patent', 'id'], ['foreigncitation', 'patent_id']), (['temp_patent_list', 'id'], ['foreigncitation', 'patent_id']), (['patent', 'id'], ['government_interest', 'patent_id']), (['temp_patent_list', 'id'], ['government_interest', 'patent_id']), (['patent', 'id'], ['ipcr', 'patent_id']), (['temp_patent_list', 'id'], ['ipcr', 'patent_id']),  (['patent', 'id'], ['nber', 'patent_id']), (['temp_patent_list', 'id'], ['nber', 'patent_id']), (['patent', 'id'], ['non_inventor_applicant', 'patent_id']), (['temp_patent_list', 'id'], ['non_inventor_applicant', 'patent_id']), (['patent', 'id'], ['otherreference', 'patent_id']), (['temp_patent_list', 'id'], ['otherreference', 'patent_id']), (['patent', 'id'], ['patent_assignee', 'patent_id']), (['temp_patent_list', 'id'], ['patent_assignee', 'patent_id']), (['assignee', 'id'], ['patent_assignee', 'assignee_id']), (['patent', 'id'], ['patent_contractawardnumber', 'patent_id']), (['temp_patent_list', 'id'], ['patent_contractawardnumber', 'patent_id']), (['patent', 'id'], ['patent_govintorg', 'patent_id']), (['temp_patent_list', 'id'], ['patent_govintorg', 'patent_id']), (['government_organization', 'organization_id'], ['patent_govintorg', 'organization_id']), (['patent', 'id'], ['patent_inventor', 'patent_id']), (['temp_patent_list', 'id'], ['patent_inventor', 'patent_id']), (['inventor', 'id'], ['patent_inventor', 'inventor_id']), (['patent', 'id'], ['patent_lawyer', 'patent_id']), (['temp_patent_list', 'id'], ['patent_lawyer', 'patent_id']), (['lawyer', 'id'], ['patent_lawyer', 'lawyer_id']), (['patent', 'id'], ['pct_data', 'patent_id']), (['temp_patent_list', 'id'], ['pct_data', 'patent_id']), (['patent', 'id'], ['rawassignee', 'patent_id']), (['temp_patent_list', 'id'], ['rawassignee', 'patent_id']), (['assignee', 'id'], ['rawassignee', 'assignee_id']), (['patent', 'id'], ['rawexaminer', 'patent_id']), (['temp_patent_list', 'id'], ['rawexaminer', 'patent_id']),   (['patent', 'id'], ['rawlawyer', 'patent_id']), (['temp_patent_list', 'id'], ['rawlawyer', 'patent_id']), (['lawyer', 'id'], ['rawlawyer', 'lawyer_id']), (['patent', 'id'], ['rel_app_text', 'patent_id']), (['temp_patent_list', 'id'], ['rel_app_text', 'patent_id']), (['patent', 'id'], ['us_term_of_grant', 'patent_id']), (['temp_patent_list', 'id'], ['us_term_of_grant', 'patent_id']), (['patent', 'id'], ['usapplicationcitation', 'patent_id']), (['temp_patent_list', 'id'], ['usapplicationcitation', 'patent_id']), (['patent', 'id'], ['uspatentcitation', 'patent_id']), (['temp_patent_list', 'id'], ['uspatentcitation', 'patent_id']), (['patent', 'id'], ['uspc_current', 'patent_id']), (['temp_patent_list', 'id'], ['uspc_current', 'patent_id']), (['patent', 'id'], ['uspc', 'patent_id']), (['temp_patent_list', 'id'], ['uspc', 'patent_id']), (['patent', 'id'], ['usreldoc', 'patent_id']), (['temp_patent_list', 'id'], ['usreldoc', 'patent_id']), (['patent', 'id'], ['wipo', 'patent_id']), (['temp_patent_list', 'id'], ['wipo', 'patent_id'])]
def right_joins(new_database, previous_qa_loc, new_qa_loc):
        '''new_database: new database
       previous_qa_loc: location of previous qa document
       new_qa_loc: location of new qa document
       this function does all right joins that follow the same pattern 
       in the new database and writes output to a csv file'''
    results = pd.read_excel("{0}/3_right_joins_standard.xlsx".format(previous_qa_loc))
    right_joins = []
    id_list=[]
    for i, j in data_list:
        conn = engine.connect()
        var = pd.read_sql("select count(distinct {0}.{1}) from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null".format(i[0], i[1], j[0], j[1]), conn)
        count = [row[0] for row in var][0]
        right_joins.append("There are {0} rows in {1} not in {2}".format(count, i[0], j[0]))
        if count >0: #ie if there are any rows in the left table not in the right 
            var_ids = pd.read_sql("select distinct {0}.{1} from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null limit 5".format(i[0], i[1], j[0], j[1]), conn)
            ids_Sql = [row[0] for row in var_ids][0]
            ids= ids_sql.values.T.tolist()
            id_list.append(ids[0])
        else:
            id_list.append('none')
    conn.close()
    return right_joins, id_list
    results['Description_{0}'.format(new_database)]= right_joins
    results['Example missing IDS_{0}'.format(new_database)]= id_list

def write_standard(right_joins,id_list, new_database, previous_qa_loc, new_qa_loc ):
    results.to_csv("{0}/09_right_joins".format(new_qa_loc), index = False)
    
right_joins_id_list = right_joins(new_database, previous_qa_loc, new_qa_loc)
write_standard(right_joins,id_list_new, new_database, previous_qa_loc, new_qa_loc )
# Out:
#   File "<tokenize>", line 31
#     results = pd.read_excel("{0}/3_right_joins_standard.xlsx".format(previous_qa_loc))
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
engine = general_helpers.connect_to_db(host, username, password, new_database)
data = pd.read_excel("{}/3_right_joins_standard.xlsx".format(previous_qa_loc))
#print (data.head())

# %%
data_list = [(['patent', 'id'], ['application', 'patent_id']), (['temp_patent_list', 'id'], ['application', 'patent_id']), (['patent', 'id'], ['brf_sum_text', 'patent_id']), (['temp_patent_list', 'id'], ['brf_sum_text', 'patent_id']), (['patent', 'id'], ['claim', 'patent_id']), (['temp_patent_list', 'id'], ['claim', 'patent_id']), (['patent', 'id'], ['cpc_current', 'patent_id']), (['temp_patent_list', 'id'], ['cpc_current', 'patent_id']), (['patent', 'id'], ['detail_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['detail_desc_text', 'patent_id']), (['patent', 'id'], ['draw_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['draw_desc_text', 'patent_id']), (['patent', 'id'], ['figures', 'patent_id']), (['temp_patent_list', 'id'], ['figures', 'patent_id']), (['patent', 'id'], ['foreign_priority', 'patent_id']), (['temp_patent_list', 'id'], ['foreign_priority', 'patent_id']), (['patent', 'id'], ['foreigncitation', 'patent_id']), (['temp_patent_list', 'id'], ['foreigncitation', 'patent_id']), (['patent', 'id'], ['government_interest', 'patent_id']), (['temp_patent_list', 'id'], ['government_interest', 'patent_id']), (['patent', 'id'], ['ipcr', 'patent_id']), (['temp_patent_list', 'id'], ['ipcr', 'patent_id']),  (['patent', 'id'], ['nber', 'patent_id']), (['temp_patent_list', 'id'], ['nber', 'patent_id']), (['patent', 'id'], ['non_inventor_applicant', 'patent_id']), (['temp_patent_list', 'id'], ['non_inventor_applicant', 'patent_id']), (['patent', 'id'], ['otherreference', 'patent_id']), (['temp_patent_list', 'id'], ['otherreference', 'patent_id']), (['patent', 'id'], ['patent_assignee', 'patent_id']), (['temp_patent_list', 'id'], ['patent_assignee', 'patent_id']), (['assignee', 'id'], ['patent_assignee', 'assignee_id']), (['patent', 'id'], ['patent_contractawardnumber', 'patent_id']), (['temp_patent_list', 'id'], ['patent_contractawardnumber', 'patent_id']), (['patent', 'id'], ['patent_govintorg', 'patent_id']), (['temp_patent_list', 'id'], ['patent_govintorg', 'patent_id']), (['government_organization', 'organization_id'], ['patent_govintorg', 'organization_id']), (['patent', 'id'], ['patent_inventor', 'patent_id']), (['temp_patent_list', 'id'], ['patent_inventor', 'patent_id']), (['inventor', 'id'], ['patent_inventor', 'inventor_id']), (['patent', 'id'], ['patent_lawyer', 'patent_id']), (['temp_patent_list', 'id'], ['patent_lawyer', 'patent_id']), (['lawyer', 'id'], ['patent_lawyer', 'lawyer_id']), (['patent', 'id'], ['pct_data', 'patent_id']), (['temp_patent_list', 'id'], ['pct_data', 'patent_id']), (['patent', 'id'], ['rawassignee', 'patent_id']), (['temp_patent_list', 'id'], ['rawassignee', 'patent_id']), (['assignee', 'id'], ['rawassignee', 'assignee_id']), (['patent', 'id'], ['rawexaminer', 'patent_id']), (['temp_patent_list', 'id'], ['rawexaminer', 'patent_id']),   (['patent', 'id'], ['rawlawyer', 'patent_id']), (['temp_patent_list', 'id'], ['rawlawyer', 'patent_id']), (['lawyer', 'id'], ['rawlawyer', 'lawyer_id']), (['patent', 'id'], ['rel_app_text', 'patent_id']), (['temp_patent_list', 'id'], ['rel_app_text', 'patent_id']), (['patent', 'id'], ['us_term_of_grant', 'patent_id']), (['temp_patent_list', 'id'], ['us_term_of_grant', 'patent_id']), (['patent', 'id'], ['usapplicationcitation', 'patent_id']), (['temp_patent_list', 'id'], ['usapplicationcitation', 'patent_id']), (['patent', 'id'], ['uspatentcitation', 'patent_id']), (['temp_patent_list', 'id'], ['uspatentcitation', 'patent_id']), (['patent', 'id'], ['uspc_current', 'patent_id']), (['temp_patent_list', 'id'], ['uspc_current', 'patent_id']), (['patent', 'id'], ['uspc', 'patent_id']), (['temp_patent_list', 'id'], ['uspc', 'patent_id']), (['patent', 'id'], ['usreldoc', 'patent_id']), (['temp_patent_list', 'id'], ['usreldoc', 'patent_id']), (['patent', 'id'], ['wipo', 'patent_id']), (['temp_patent_list', 'id'], ['wipo', 'patent_id'])]

results = pd.read_excel("{0}/3_right_joins_standard.xlsx".format(previous_qa_loc))
right_joins = []
id_list=[]
engine.execute('use {}'.format(new_database))
for i, j in data_list:
    var = engine.execute("select count(distinct {0}.{1}) from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null".format(i[0], i[1], j[0], j[1]))
    count = [row[0] for row in var][0]
    right_joins.append("There are {0} rows in {1} not in {2}".format(count, i[0], j[0]))
    print (right_joins)
    if var[0][0] >0: #ie if there are any rows in the left table not in the right 
        ids_sql = pd.read_sql("select distinct {0}.{1} from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null limit 5".format(i[0], i[1], j[0], j[1]), mydb)
        ids= ids_sql.values.T.tolist()
        id_list.append(ids[0])
    else:
        id_list.append('none')
return right_joins, id_list
# Out:
# ['There are 0 rows in patent not in application']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg', 'There are 168347 rows in temp_patent_list not in patent_govintorg']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg', 'There are 168347 rows in temp_patent_list not in patent_govintorg', 'There are 3 rows in government_organization not in patent_govintorg']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg', 'There are 168347 rows in temp_patent_list not in patent_govintorg', 'There are 3 rows in government_organization not in patent_govintorg', 'There are 842 rows in patent not in patent_inventor']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg', 'There are 168347 rows in temp_patent_list not in patent_govintorg', 'There are 3 rows in government_organization not in patent_govintorg', 'There are 842 rows in patent not in patent_inventor', 'There are 1 rows in temp_patent_list not in patent_inventor']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg', 'There are 168347 rows in temp_patent_list not in patent_govintorg', 'There are 3 rows in government_organization not in patent_govintorg', 'There are 842 rows in patent not in patent_inventor', 'There are 1 rows in temp_patent_list not in patent_inventor', 'There are 9 rows in inventor not in patent_inventor']
# ...
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg', 'There are 168347 rows in temp_patent_list not in patent_govintorg', 'There are 3 rows in government_organization not in patent_govintorg', 'There are 842 rows in patent not in patent_inventor', 'There are 1 rows in temp_patent_list not in patent_inventor', 'There are 9 rows in inventor not in patent_inventor', 'There are 513929 rows in patent not in patent_lawyer', 'There are 12525 rows in temp_patent_list not in patent_lawyer', 'There are 6 rows in lawyer not in patent_lawyer', 'There are 6163595 rows in patent not in pct_data', 'There are 140324 rows in temp_patent_list not in pct_data', 'There are 945902 rows in patent not in rawassignee', 'There are 11764 rows in temp_patent_list not in rawassignee', 'There are 0 rows in assignee not in rawassignee', 'There are 1559 rows in patent not in rawexaminer', 'There are 0 rows in temp_patent_list not in rawexaminer', 'There are 513929 rows in patent not in rawlawyer', 'There are 12525 rows in temp_patent_list not in rawlawyer', 'There are 6 rows in lawyer not in rawlawyer', 'There are 5202160 rows in patent not in rel_app_text', 'There are 106565 rows in temp_patent_list not in rel_app_text', 'There are 3603401 rows in patent not in us_term_of_grant', 'There are 60154 rows in temp_patent_list not in us_term_of_grant', 'There are 4064799 rows in patent not in usapplicationcitation', 'There are 15892 rows in temp_patent_list not in usapplicationcitation', 'There are 352977 rows in patent not in uspatentcitation', 'There are 22123 rows in temp_patent_list not in uspatentcitation', 'There are 205527 rows in patent not in uspc_current', 'There are 168345 rows in temp_patent_list not in uspc_current', 'There are 1764775 rows in patent not in uspc', 'There are 168345 rows in temp_patent_list not in uspc', 'There are 3379013 rows in patent not in usreldoc']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg', 'There are 168347 rows in temp_patent_list not in patent_govintorg', 'There are 3 rows in government_organization not in patent_govintorg', 'There are 842 rows in patent not in patent_inventor', 'There are 1 rows in temp_patent_list not in patent_inventor', 'There are 9 rows in inventor not in patent_inventor', 'There are 513929 rows in patent not in patent_lawyer', 'There are 12525 rows in temp_patent_list not in patent_lawyer', 'There are 6 rows in lawyer not in patent_lawyer', 'There are 6163595 rows in patent not in pct_data', 'There are 140324 rows in temp_patent_list not in pct_data', 'There are 945902 rows in patent not in rawassignee', 'There are 11764 rows in temp_patent_list not in rawassignee', 'There are 0 rows in assignee not in rawassignee', 'There are 1559 rows in patent not in rawexaminer', 'There are 0 rows in temp_patent_list not in rawexaminer', 'There are 513929 rows in patent not in rawlawyer', 'There are 12525 rows in temp_patent_list not in rawlawyer', 'There are 6 rows in lawyer not in rawlawyer', 'There are 5202160 rows in patent not in rel_app_text', 'There are 106565 rows in temp_patent_list not in rel_app_text', 'There are 3603401 rows in patent not in us_term_of_grant', 'There are 60154 rows in temp_patent_list not in us_term_of_grant', 'There are 4064799 rows in patent not in usapplicationcitation', 'There are 15892 rows in temp_patent_list not in usapplicationcitation', 'There are 352977 rows in patent not in uspatentcitation', 'There are 22123 rows in temp_patent_list not in uspatentcitation', 'There are 205527 rows in patent not in uspc_current', 'There are 168345 rows in temp_patent_list not in uspc_current', 'There are 1764775 rows in patent not in uspc', 'There are 168345 rows in temp_patent_list not in uspc', 'There are 3379013 rows in patent not in usreldoc', 'There are 22460 rows in temp_patent_list not in usreldoc']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg', 'There are 168347 rows in temp_patent_list not in patent_govintorg', 'There are 3 rows in government_organization not in patent_govintorg', 'There are 842 rows in patent not in patent_inventor', 'There are 1 rows in temp_patent_list not in patent_inventor', 'There are 9 rows in inventor not in patent_inventor', 'There are 513929 rows in patent not in patent_lawyer', 'There are 12525 rows in temp_patent_list not in patent_lawyer', 'There are 6 rows in lawyer not in patent_lawyer', 'There are 6163595 rows in patent not in pct_data', 'There are 140324 rows in temp_patent_list not in pct_data', 'There are 945902 rows in patent not in rawassignee', 'There are 11764 rows in temp_patent_list not in rawassignee', 'There are 0 rows in assignee not in rawassignee', 'There are 1559 rows in patent not in rawexaminer', 'There are 0 rows in temp_patent_list not in rawexaminer', 'There are 513929 rows in patent not in rawlawyer', 'There are 12525 rows in temp_patent_list not in rawlawyer', 'There are 6 rows in lawyer not in rawlawyer', 'There are 5202160 rows in patent not in rel_app_text', 'There are 106565 rows in temp_patent_list not in rel_app_text', 'There are 3603401 rows in patent not in us_term_of_grant', 'There are 60154 rows in temp_patent_list not in us_term_of_grant', 'There are 4064799 rows in patent not in usapplicationcitation', 'There are 15892 rows in temp_patent_list not in usapplicationcitation', 'There are 352977 rows in patent not in uspatentcitation', 'There are 22123 rows in temp_patent_list not in uspatentcitation', 'There are 205527 rows in patent not in uspc_current', 'There are 168345 rows in temp_patent_list not in uspc_current', 'There are 1764775 rows in patent not in uspc', 'There are 168345 rows in temp_patent_list not in uspc', 'There are 3379013 rows in patent not in usreldoc', 'There are 22460 rows in temp_patent_list not in usreldoc', 'There are 674486 rows in patent not in wipo']
# ['There are 0 rows in patent not in application', 'There are 0 rows in temp_patent_list not in application', 'There are 593385 rows in patent not in brf_sum_text', 'There are 15494 rows in temp_patent_list not in brf_sum_text', 'There are 624 rows in patent not in claim', 'There are 0 rows in temp_patent_list not in claim', 'There are 671819 rows in patent not in cpc_current', 'There are 42384 rows in temp_patent_list not in cpc_current', 'There are 2862903 rows in patent not in detail_desc_text', 'There are 15494 rows in temp_patent_list not in detail_desc_text', 'There are 653300 rows in patent not in draw_desc_text', 'There are 6019 rows in temp_patent_list not in draw_desc_text', 'There are 506049 rows in patent not in figures', 'There are 5637 rows in temp_patent_list not in figures', 'There are 4275459 rows in patent not in foreign_priority', 'There are 108018 rows in temp_patent_list not in foreign_priority', 'There are 3180843 rows in patent not in foreigncitation', 'There are 60348 rows in temp_patent_list not in foreigncitation', 'There are 6681633 rows in patent not in government_interest', 'There are 167962 rows in temp_patent_list not in government_interest', 'There are 440527 rows in patent not in ipcr', 'There are 15494 rows in temp_patent_list not in ipcr', 'There are 1713425 rows in patent not in nber', 'There are 171663 rows in temp_patent_list not in nber', 'There are 4866673 rows in patent not in non_inventor_applicant', 'There are 0 rows in temp_patent_list not in non_inventor_applicant', 'There are 3814255 rows in patent not in otherreference', 'There are 59439 rows in temp_patent_list not in otherreference', 'There are 945902 rows in patent not in patent_assignee', 'There are 11764 rows in temp_patent_list not in patent_assignee', 'There are 0 rows in assignee not in patent_assignee', 'There are 6711075 rows in patent not in patent_contractawardnumber', 'There are 168575 rows in temp_patent_list not in patent_contractawardnumber', 'There are 6684439 rows in patent not in patent_govintorg', 'There are 168347 rows in temp_patent_list not in patent_govintorg', 'There are 3 rows in government_organization not in patent_govintorg', 'There are 842 rows in patent not in patent_inventor', 'There are 1 rows in temp_patent_list not in patent_inventor', 'There are 9 rows in inventor not in patent_inventor', 'There are 513929 rows in patent not in patent_lawyer', 'There are 12525 rows in temp_patent_list not in patent_lawyer', 'There are 6 rows in lawyer not in patent_lawyer', 'There are 6163595 rows in patent not in pct_data', 'There are 140324 rows in temp_patent_list not in pct_data', 'There are 945902 rows in patent not in rawassignee', 'There are 11764 rows in temp_patent_list not in rawassignee', 'There are 0 rows in assignee not in rawassignee', 'There are 1559 rows in patent not in rawexaminer', 'There are 0 rows in temp_patent_list not in rawexaminer', 'There are 513929 rows in patent not in rawlawyer', 'There are 12525 rows in temp_patent_list not in rawlawyer', 'There are 6 rows in lawyer not in rawlawyer', 'There are 5202160 rows in patent not in rel_app_text', 'There are 106565 rows in temp_patent_list not in rel_app_text', 'There are 3603401 rows in patent not in us_term_of_grant', 'There are 60154 rows in temp_patent_list not in us_term_of_grant', 'There are 4064799 rows in patent not in usapplicationcitation', 'There are 15892 rows in temp_patent_list not in usapplicationcitation', 'There are 352977 rows in patent not in uspatentcitation', 'There are 22123 rows in temp_patent_list not in uspatentcitation', 'There are 205527 rows in patent not in uspc_current', 'There are 168345 rows in temp_patent_list not in uspc_current', 'There are 1764775 rows in patent not in uspc', 'There are 168345 rows in temp_patent_list not in uspc', 'There are 3379013 rows in patent not in usreldoc', 'There are 22460 rows in temp_patent_list not in usreldoc', 'There are 674486 rows in patent not in wipo', 'There are 42406  ...

# %%
data_list = [(['patent', 'id'], ['application', 'patent_id']), (['temp_patent_list', 'id'], ['application', 'patent_id']), (['patent', 'id'], ['brf_sum_text', 'patent_id']), (['temp_patent_list', 'id'], ['brf_sum_text', 'patent_id']), (['patent', 'id'], ['claim', 'patent_id']), (['temp_patent_list', 'id'], ['claim', 'patent_id']), (['patent', 'id'], ['cpc_current', 'patent_id']), (['temp_patent_list', 'id'], ['cpc_current', 'patent_id']), (['patent', 'id'], ['detail_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['detail_desc_text', 'patent_id']), (['patent', 'id'], ['draw_desc_text', 'patent_id']), (['temp_patent_list', 'id'], ['draw_desc_text', 'patent_id']), (['patent', 'id'], ['figures', 'patent_id']), (['temp_patent_list', 'id'], ['figures', 'patent_id']), (['patent', 'id'], ['foreign_priority', 'patent_id']), (['temp_patent_list', 'id'], ['foreign_priority', 'patent_id']), (['patent', 'id'], ['foreigncitation', 'patent_id']), (['temp_patent_list', 'id'], ['foreigncitation', 'patent_id']), (['patent', 'id'], ['government_interest', 'patent_id']), (['temp_patent_list', 'id'], ['government_interest', 'patent_id']), (['patent', 'id'], ['ipcr', 'patent_id']), (['temp_patent_list', 'id'], ['ipcr', 'patent_id']),  (['patent', 'id'], ['nber', 'patent_id']), (['temp_patent_list', 'id'], ['nber', 'patent_id']), (['patent', 'id'], ['non_inventor_applicant', 'patent_id']), (['temp_patent_list', 'id'], ['non_inventor_applicant', 'patent_id']), (['patent', 'id'], ['otherreference', 'patent_id']), (['temp_patent_list', 'id'], ['otherreference', 'patent_id']), (['patent', 'id'], ['patent_assignee', 'patent_id']), (['temp_patent_list', 'id'], ['patent_assignee', 'patent_id']), (['assignee', 'id'], ['patent_assignee', 'assignee_id']), (['patent', 'id'], ['patent_contractawardnumber', 'patent_id']), (['temp_patent_list', 'id'], ['patent_contractawardnumber', 'patent_id']), (['patent', 'id'], ['patent_govintorg', 'patent_id']), (['temp_patent_list', 'id'], ['patent_govintorg', 'patent_id']), (['government_organization', 'organization_id'], ['patent_govintorg', 'organization_id']), (['patent', 'id'], ['patent_inventor', 'patent_id']), (['temp_patent_list', 'id'], ['patent_inventor', 'patent_id']), (['inventor', 'id'], ['patent_inventor', 'inventor_id']), (['patent', 'id'], ['patent_lawyer', 'patent_id']), (['temp_patent_list', 'id'], ['patent_lawyer', 'patent_id']), (['lawyer', 'id'], ['patent_lawyer', 'lawyer_id']), (['patent', 'id'], ['pct_data', 'patent_id']), (['temp_patent_list', 'id'], ['pct_data', 'patent_id']), (['patent', 'id'], ['rawassignee', 'patent_id']), (['temp_patent_list', 'id'], ['rawassignee', 'patent_id']), (['assignee', 'id'], ['rawassignee', 'assignee_id']), (['patent', 'id'], ['rawexaminer', 'patent_id']), (['temp_patent_list', 'id'], ['rawexaminer', 'patent_id']),   (['patent', 'id'], ['rawlawyer', 'patent_id']), (['temp_patent_list', 'id'], ['rawlawyer', 'patent_id']), (['lawyer', 'id'], ['rawlawyer', 'lawyer_id']), (['patent', 'id'], ['rel_app_text', 'patent_id']), (['temp_patent_list', 'id'], ['rel_app_text', 'patent_id']), (['patent', 'id'], ['us_term_of_grant', 'patent_id']), (['temp_patent_list', 'id'], ['us_term_of_grant', 'patent_id']), (['patent', 'id'], ['usapplicationcitation', 'patent_id']), (['temp_patent_list', 'id'], ['usapplicationcitation', 'patent_id']), (['patent', 'id'], ['uspatentcitation', 'patent_id']), (['temp_patent_list', 'id'], ['uspatentcitation', 'patent_id']), (['patent', 'id'], ['uspc_current', 'patent_id']), (['temp_patent_list', 'id'], ['uspc_current', 'patent_id']), (['patent', 'id'], ['uspc', 'patent_id']), (['temp_patent_list', 'id'], ['uspc', 'patent_id']), (['patent', 'id'], ['usreldoc', 'patent_id']), (['temp_patent_list', 'id'], ['usreldoc', 'patent_id']), (['patent', 'id'], ['wipo', 'patent_id']), (['temp_patent_list', 'id'], ['wipo', 'patent_id'])]
def right_joins(new_database, previous_qa_loc, new_qa_loc):
        '''new_database: new database
       previous_qa_loc: location of previous qa document
       new_qa_loc: location of new qa document
       this function does all right joins that follow the same pattern 
       in the new database and writes output to a csv file'''
        results = pd.read_excel("{0}/3_right_joins_standard.xlsx".format(previous_qa_loc))
        right_joins = []
        id_list=[]
        cursor.execute('use {}'.format(new_database))
        for i, j in data_list:
            cursor.execute("select count(distinct {0}.{1}) from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null".format(i[0], i[1], j[0], j[1]))
            var = cursor.fetchall()
            print i, j, var
            right_joins.append("There are {0} rows in {1} not in {2}".format(var[0][0], i[0], j[0]))
            if var[0][0] >0: #ie if there are any rows in the left table not in the right 
                ids_sql = pd.read_sql("select distinct {0}.{1} from {2} right join {0} on {0}.{1} = {2}.{3} where {2}.{3} is null limit 5".format(i[0], i[1], j[0], j[1]), mydb)
                ids= ids_sql.values.T.tolist()
                id_list.append(ids[0])
            else:
                id_list.append('none')
        return right_joins, id_list
def write_standard(right_joins,id_list, new_database, previous_qa_loc, new_qa_loc ):
    results = pd.read_excel("{0}/3_right_joins_standard.xlsx".format(previous_qa_loc))
    results['Description_{0}'.format(new_database)]= right_joins
    results['Example missing IDS_{0}'.format(new_database)]= id_list
    results.to_excel("{0}/3_right_joins_standard.xlsx".format(new_qa_loc), index = False)

# %%
right_joins,id_lis = right_joins(new_database, previous_qa_loc, new_qa_loc)
write_standard(right_joins,id_list_new, new_database, previous_qa_loc, new_qa_loc )
